# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Titanic-Dataset.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # categorical Data

# %% [markdown]
# ## 1] Count Plot

# %%
# Invalid syntax# sns.countplot(df['Survived'])
# plt.show()

sns.countplot(x='Survived', data=df)
plt.show()
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
sns.countplot(x='Pclass', data=df)
plt.show()
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
sns.countplot(x='Sex', data=df)
plt.show()
df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
sns.countplot(x='SibSp', data=df)
plt.show()
df['SibSp'].value_counts()
# Out:
# SibSp
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: count, dtype: int64

# %%
sns.countplot(x='Parch', data=df)
plt.show()
df['Parch'].value_counts()
# Out:
# Parch
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: count, dtype: int64

# %%
sns.countplot(x="Embarked",data=df)
plt.show()
df["Embarked"].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %% [markdown]
# ## Pie Chart

# %%
df['Survived'].value_counts().plot(kind='pie',autopct='%.2f')
plt.show()

# %%
# Survived	Pclass	Name	Sex	Age	SibSp	Parch	Ticket	Fare	Cabin	Embarked

# %%
df['Pclass'].value_counts().plot(kind='pie',autopct='%.2f')
plt.show()

# %%
df['Sex'].value_counts().plot(kind='pie',autopct='%.2f')
plt.show()

# %%
df['SibSp'].value_counts().plot(kind='pie',autopct='%.2f')
plt.show()

# %%
df['Parch'].value_counts().plot(kind='pie',autopct='%.2f')
plt.show()

# %%
df['Embarked'].value_counts().plot(kind='pie',autopct='%.2f')
plt.show()

# %%
# This happen beacause everyone has differnt ticket so it is cnsidered as each category ,dont do this 
df['Ticket'].value_counts().plot(kind='pie',autopct='%.2f')
plt.show()

# %% [markdown]
# # numerical Data

# %% [markdown]
# ## Histogram

# %%
plt.hist(df['Age'])
plt.show()

# %%
sns.histplot(df['Age'])
plt.show()

# %%
import numpy as np

# %% [markdown]
# ## Distplot

# %%
sns.distplot(df['Age'])
plt.show()
# Out:
# C:\Users\Rajvardhan\AppData\Local\Temp\ipykernel_20340\1599895865.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])

# %%
sns.histplot(df['Age'], kde=True)
plt.show()

# %%
sns.histplot(df['Fare'], kde=True )
plt.show()

# %% [markdown]
# ## Boxplot

# %%
sns.boxplot(x="Fare",data=df)
plt.show()

# %%
sns.boxplot(df["Fare"])
plt.show()

# %%
sns.boxplot(x="Age",data=df)
plt.show()

# %%
float(df['Fare'].skew())
# Out:
# 4.787316519674893
