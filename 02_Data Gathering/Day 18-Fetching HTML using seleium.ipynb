# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
pip install selenium
# Out:
# ...
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.6 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.6 MB 715.6 kB/s eta 0:00:13
#    -- ------------------------------------- 0.5/9.6 MB 715.6 kB/s eta 0:00:13
#    --- ------------------------------------ 0.8/9.6 MB 703.4 kB/s eta 0:00:13
#    ---- ----------------------------------- 1.0/9.6 MB 772.5 kB/s eta 0:00:12
#    ---- ----------------------------------- 1.0/9.6 MB 772.5 kB/s eta 0:00:12
#    ----- ---------------------------------- 1.3/9.6 MB 836.4 kB/s eta 0:00:10
# ...

# %%
pip install webdriver-manager
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
requests.get('https://www.ambitionbox.com/list-of-companies').text
# Out:
# '<HTML><HEAD>\n<TITLE>Access Denied</TITLE>\n</HEAD><BODY>\n<H1>Access Denied</H1>\n \nYou don\'t have permission to access "http&#58;&#47;&#47;www&#46;ambitionbox&#46;com&#47;list&#45;of&#45;companies" on this server.<P>\nReference&#32;&#35;18&#46;c4fed417&#46;1755869635&#46;f6a4eec\n<P>https&#58;&#47;&#47;errors&#46;edgesuite&#46;net&#47;18&#46;c4fed417&#46;1755869635&#46;f6a4eec</P>\n</BODY>\n</HTML>\n'

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By

# setup Chrome
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
driver.get("https://www.ambitionbox.com/list-of-companies")

# wait and extract content
companies = driver.find_elements(By.CSS_SELECTOR, "div.companyCardWrapper")
for c in companies:
    print(c.text)

driver.quit()
# Out:
# TCS
# Follow
# 3.5
# (1L)
# IT Services & Consulting | Bangalore / Bengaluru +412 other locations
# HIGHLY RATED FOR
# Job Security
# CRITICALLY RATED FOR
# Promotions / Appraisal, Salary & Benefits, Work Satisfaction
# To view salary insights
# Select designation
# 1L
# Reviews
# 9.5L
# Salaries
# 11.3k
# Interviews
# 92
# Jobs
# 10.6k
# Benefits
# 86
# Photos
# Accenture
# Follow
# 3.7
# (65.5k)
# IT Services & Consulting | Bangalore / Bengaluru +232 other locations
# CRITICALLY RATED FOR
# Promotions / Appraisal, Salary & Benefits, Work Satisfaction
# To view salary insights
# Select designation
# 65.5k
# Reviews
# 6.3L
# Salaries
# 8.8k
# Interviews
# 25.6k
# Jobs
# 6.7k
# Benefits
# 48
# Photos
# Wipro
# Follow
# 3.7
# (58.9k)
# IT Services & Consulting | Bangalore / Bengaluru +358 other locations
# HIGHLY RATED FOR
# Job Security
# CRITICALLY RATED FOR
# Promotions / Appraisal, Salary & Benefits, Work Satisfaction
# To view salary insights
# Select designation
# 58.9k
# ...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
driver.get("https://www.ambitionbox.com/list-of-companies")

# Get the whole page HTML
html_data = driver.page_source
print(html_data[:2000])   # print only first 2000 chars for preview

# OR get only the company list container
container = driver.find_element(By.CSS_SELECTOR, "div.companyCardWrapper").get_attribute("outerHTML")
print(container)

driver.quit()
# Out:
# <html lang="en" class=" " style="--vh: 6.51px; --dd-width: 351.4px;"><head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width,initial-scale=1,minimum-scale=1">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <link rel="manifest" href="/assets/next/manifest.json">
#     <style>@media only screen and (min-width:767px){.trp-img{width:400px!important;max-width:400px!important}}</style>
#     <script src="/static/js/env-runtime.js"></script>
#     <script>window.dataLayer=window.dataLayer||[],window.gtag=window.gtag||function(){window.dataLayer.push(arguments)},gtag("js",new Date),window.initialDate=(new Date).toISOString()</script>
# ...
