# %%
import requests

url = "https://instagram120.p.rapidapi.com/api/instagram/userInfo"

payload = { "username": "instagram" }
headers = {
	"x-rapidapi-key": "507b37df13msh479715189576570p16bfd8jsndb35155ca1b2",
	"x-rapidapi-host": "instagram120.p.rapidapi.com",
	"Content-Type": "application/json"
}

response = requests.post(url, json=payload, headers=headers)

print(response.json())
# Out:
# {'result': [{'user': {'can_hide_category': True, 'account_type': 3, 'ads_page_id': None, 'ads_page_name': None, 'current_catalog_id': None, 'mini_shop_seller_onboarding_status': None, 'ads_incentive_expiration_date': None, 'has_ig_profile': True, 'fbid_v2': '17841400039600391', 'full_name': 'Instagram', 'pk_id': '25025320', 'pk': '25025320', 'primary_profile_link_type': 0, 'show_fb_link_on_profile': False, 'show_fb_page_link_on_profile': False, 'account_category': '', 'can_add_fb_group_link_on_profile': False, 'can_use_affiliate_partnership_messaging_as_creator': False, 'can_use_affiliate_partnership_messaging_as_brand': False, 'existing_user_age_collection_enabled': True, 'feed_post_reshare_disabled': False, 'has_gen_ai_personas_for_profile_banner': False, 'has_guides': False, 'has_nme_badge': False, 'has_public_tab_threads': True, 'highlight_reshare_disabled': False, 'highlights_tray_type': 'DEFAULT', 'include_direct_blacklist_status': True, 'is_direct_roll_call_enabled': True, 'is
# ...

# %%
import requests

url = "https://imdb8.p.rapidapi.com/title/v2/get-awards"

querystring = {"tconst":"tt0120338","first":"20","country":"US","language":"en-US"}

headers = {
	"x-rapidapi-key": "507b37df13msh479715189576570p16bfd8jsndb35155ca1b2",
	"x-rapidapi-host": "imdb8.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'data': {'title': {'id': 'tt0120338', 'awardNominations': {'total': 210, 'pageInfo': {'__typename': 'PageInfo', 'hasNextPage': True, 'hasPreviousPage': False, 'startCursor': 'YW4wMDIyMTAy', 'endCursor': 'YW4wMDM1MDc1'}, 'edges': [{'node': {'__typename': 'AwardNomination', 'id': 'an0022102', 'isWinner': False, 'winningRank': None, 'category': {'text': 'Best Picture'}, 'notes': None, 'award': {'id': 'aw0001583', 'eventEdition': {'id': 'ee0030893', 'year': 1998, 'instanceWithinYear': 1, 'event': {'id': 'ev0000163', 'text': 'Chicago Film Critics Association Awards'}}, 'awardName': 'CFCA Award'}, 'awardedEntities': {'__typename': 'AwardedTitles', 'awardTitles': [{'__typename': 'AwardTitle', 'title': {'__typename': 'Title', 'id': 'tt0120338', 'titleText': {'text': 'Titanic', 'isOriginalTitle': True}, 'originalTitleText': {'text': 'Titanic', 'isOriginalTitle': True}, 'releaseYear': {'__typename': 'YearRange', 'year': 1997, 'endYear': None}, 'releaseDate': {'__typename': 'ReleaseDate', 'mon
# ...

# %%
(response.json()['data']['title']['awardNominations']['edges'])
# Out:
# [{'node': {'__typename': 'AwardNomination',
#    'id': 'an0022102',
#    'isWinner': False,
#    'winningRank': None,
#    'category': {'text': 'Best Picture'},
#    'notes': None,
#    'award': {'id': 'aw0001583',
#     'eventEdition': {'id': 'ee0030893',
#      'year': 1998,
#      'instanceWithinYear': 1,
#      'event': {'id': 'ev0000163',
#       'text': 'Chicago Film Critics Association Awards'}},
#     'awardName': 'CFCA Award'},
#    'awardedEntities': {'__typename': 'AwardedTitles',
#     'awardTitles': [{'__typename': 'AwardTitle',
#       'title': {'__typename': 'Title',
#        'id': 'tt0120338',
#        'titleText': {'text': 'Titanic', 'isOriginalTitle': True},
#        'originalTitleText': {'text': 'Titanic', 'isOriginalTitle': True},
#        'releaseYear': {'__typename': 'YearRange',
#         'year': 1997,
#         'endYear': None},
#        'releaseDate': {'__typename': 'ReleaseDate',
#         'month': 12,
#         'day': 19,
#         'year': 1997,
# ...

# %%
import pandas as pd

# %%
df = pd.DataFrame((response.json()['data']['title']['awardNominations']['edges']))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 df = pd.DataFrame((response.json()['data']['title']['awardNominations']['edges']))
#
# KeyError: 'data'

# %%
df
# Out:
#                                                  node
# 0   {'__typename': 'AwardNomination', 'id': 'an002...
# 1   {'__typename': 'AwardNomination', 'id': 'an002...
# 2   {'__typename': 'AwardNomination', 'id': 'an002...
# 3   {'__typename': 'AwardNomination', 'id': 'an002...
# 4   {'__typename': 'AwardNomination', 'id': 'an002...
# 5   {'__typename': 'AwardNomination', 'id': 'an002...
# 6   {'__typename': 'AwardNomination', 'id': 'an002...
# 7   {'__typename': 'AwardNomination', 'id': 'an002...
# 8   {'__typename': 'AwardNomination', 'id': 'an002...
# 9   {'__typename': 'AwardNomination', 'id': 'an002...
# 10  {'__typename': 'AwardNomination', 'id': 'an002...
# 11  {'__typename': 'AwardNomination', 'id': 'an002...
# 12  {'__typename': 'AwardNomination', 'id': 'an003...
# 13  {'__typename': 'AwardNomination', 'id': 'an003...
# 14  {'__typename': 'AwardNomination', 'id': 'an003...
# 15  {'__typename': 'AwardNomination', 'id': 'an003...
# ...

# %%
df.columns
# Out:
# Index(['node'], dtype='object')

# %%
df = df.reset_index(drop=True)

# %%
df
# Out:
#                                                  node
# 0   {'__typename': 'AwardNomination', 'id': 'an002...
# 1   {'__typename': 'AwardNomination', 'id': 'an002...
# 2   {'__typename': 'AwardNomination', 'id': 'an002...
# 3   {'__typename': 'AwardNomination', 'id': 'an002...
# 4   {'__typename': 'AwardNomination', 'id': 'an002...
# 5   {'__typename': 'AwardNomination', 'id': 'an002...
# 6   {'__typename': 'AwardNomination', 'id': 'an002...
# 7   {'__typename': 'AwardNomination', 'id': 'an002...
# 8   {'__typename': 'AwardNomination', 'id': 'an002...
# 9   {'__typename': 'AwardNomination', 'id': 'an002...
# 10  {'__typename': 'AwardNomination', 'id': 'an002...
# 11  {'__typename': 'AwardNomination', 'id': 'an002...
# 12  {'__typename': 'AwardNomination', 'id': 'an003...
# 13  {'__typename': 'AwardNomination', 'id': 'an003...
# 14  {'__typename': 'AwardNomination', 'id': 'an003...
# 15  {'__typename': 'AwardNomination', 'id': 'an003...
# ...

# %%
df.shape
# Out:
# (20, 1)

# %%
import requests

url = "https://imdb8.p.rapidapi.com/actors/list-most-popular-celebs"

querystring = {"homeCountry":"US","currentCountry":"US","purchaseCountry":"US"}

headers = {
	"x-rapidapi-key": "507b37df13msh479715189576570p16bfd8jsndb35155ca1b2",
	"x-rapidapi-host": "imdb8.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# ['/name/nm7584896/', '/name/nm4911194/', '/name/nm3528821/', '/name/nm1199107/', '/name/nm12024632/', '/name/nm0001496/', '/name/nm3400186/', '/name/nm0015196/', '/name/nm7509200/', '/name/nm0684877/', '/name/nm2858875/', '/name/nm3867299/', '/name/nm0648249/', '/name/nm0001876/', '/name/nm0525921/', '/name/nm3948952/', '/name/nm2965015/', '/name/nm0811242/', '/name/nm0005305/', '/name/nm0005286/', '/name/nm0050959/', '/name/nm0196654/', '/name/nm4960279/', '/name/nm0000207/', '/name/nm0000525/', '/name/nm4825178/', '/name/nm6259860/', '/name/nm1279638/', '/name/nm5547023/', '/name/nm4586054/', '/name/nm3014031/', '/name/nm0000502/', '/name/nm0001191/', '/name/nm0628601/', '/name/nm0051509/', '/name/nm0000114/', '/name/nm0204583/', '/name/nm0876138/', '/name/nm0628120/', '/name/nm0517820/', '/name/nm0000033/', '/name/nm2403277/', '/name/nm1509478/', '/name/nm3641002/', '/name/nm8779346/', '/name/nm0000093/', '/name/nm9665041/', '/name/nm0424060/', '/name/nm2225369/', '/name/nm4007171
# ...

# %%
import requests

url = "https://imdb8.p.rapidapi.com/title/v2/get-box-office-summary"

querystring = {"tconst":"tt0120338","country":"US","language":"en-US"}

headers = {
	"x-rapidapi-key": "507b37df13msh479715189576570p16bfd8jsndb35155ca1b2",
	"x-rapidapi-host": "imdb8.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'data': {'title': {'__typename': 'Title', 'id': 'tt0120338', 'titleText': {'text': 'Titanic', 'isOriginalTitle': True}, 'originalTitleText': {'text': 'Titanic', 'isOriginalTitle': True}, 'releaseYear': {'year': 1997}, 'budget': {'totalBudget': {'__typename': 'Money', 'amount': 200000000, 'currency': 'USD'}}, 'openingWeekendGrosses': {'total': 1, 'edges': [{'node': {'gross': {'__typename': 'BoxOfficeGross', 'total': {'__typename': 'Money', 'amount': 28638131, 'currency': 'USD'}}, 'weekendStartDate': '1997-12-19'}}]}, 'domesticGross': {'__typename': 'BoxOfficeGross', 'total': {'__typename': 'Money', 'amount': 674354882, 'currency': 'USD'}}, 'worldwideGross': {'__typename': 'BoxOfficeGross', 'total': {'__typename': 'Money', 'amount': 2264812968, 'currency': 'USD'}}}}}

# %%
import requests

url = "https://imdb8.p.rapidapi.com/title/v2/get-awards-summary"

querystring = {"tconst":"tt0120338","country":"US","language":"en-US"}

headers = {
	"x-rapidapi-key": "507b37df13msh479715189576570p16bfd8jsndb35155ca1b2",
	"x-rapidapi-host": "imdb8.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'data': {'title': {'prestigiousAwardSummary': {'__typename': 'PrestigiousAwardSummary', 'awardNomination': {'award': {'eventEdition': {'event': {'id': 'ev0000003'}}, 'text': 'Oscar'}}, 'wins': 11, 'nominations': 3}, 'totalWins': {'total': 126}, 'totalNominations': {'total': 84}, 'ratingsSummary': {'topRanking': {'rank': 412, 'text': {'value': 'Top Rated'}}}}}}

# %%
import requests

url = "https://imdb8.p.rapidapi.com/title/v2/get-genres"

querystring = {"tconst":"tt0120338","country":"US","language":"en-US"}

headers = {
	"x-rapidapi-key": "507b37df13msh479715189576570p16bfd8jsndb35155ca1b2",
	"x-rapidapi-host": "imdb8.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'data': {'title': {'id': 'tt0120338', 'titleGenres': {'__typename': 'TitleGenres', 'genres': [{'genre': {'genreId': 'Drama', 'text': 'Drama'}}, {'genre': {'genreId': 'Romance', 'text': 'Romance'}}]}, 'titleType': {'__typename': 'TitleType', 'id': 'movie', 'text': 'Movie', 'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}], 'canHaveEpisodes': False, 'isEpisode': False, 'isSeries': False, 'displayableProperty': {'value': {'plainText': ''}}}}}}

# %%
import requests

url = "https://imdb8.p.rapidapi.com/title/v2/get-filming-locations"

querystring = {"tconst":"tt0120338","first":"20","country":"US","language":"en-US"}

headers = {
	"x-rapidapi-key": "507b37df13msh479715189576570p16bfd8jsndb35155ca1b2",
	"x-rapidapi-host": "imdb8.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'data': {'title': {'__typename': 'Title', 'id': 'tt0120338', 'titleText': {'text': 'Titanic', 'isOriginalTitle': True}, 'originalTitleText': {'text': 'Titanic', 'isOriginalTitle': True}, 'releaseYear': {'__typename': 'YearRange', 'year': 1997, 'endYear': None}, 'releaseDate': {'__typename': 'ReleaseDate', 'month': 12, 'day': 19, 'year': 1997, 'country': {'id': 'US'}, 'restriction': None, 'attributes': [], 'displayableProperty': {'qualifiersInMarkdownList': None}}, 'titleType': {'__typename': 'TitleType', 'id': 'movie', 'text': 'Movie', 'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}], 'canHaveEpisodes': False, 'isEpisode': False, 'isSeries': False, 'displayableProperty': {'value': {'plainText': ''}}}, 'primaryImage': {'__typename': 'Image', 'id': 'rm2647458304', 'url': 'https://m.media-amazon.com/images/M/MV5BYzYyN2FiZmUtYWYzMy00MzViLWJkZTMtOGY1ZjgzNWMwN2YxXkEyXkFqcGc@._V1_.jpg', 'height': 3000, 'width': 2015}, 'filmingLocations': {'__typename': 'FilmingLocationCon
# ...

# %%
import requests

url = "https://imdb8.p.rapidapi.com/title/v2/get-ratings"

querystring = {"tconst":"tt0120338","country":"US","language":"en-US"}

headers = {
	"x-rapidapi-key": "507b37df13msh479715189576570p16bfd8jsndb35155ca1b2",
	"x-rapidapi-host": "imdb8.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'data': {'title': {'__typename': 'Title', 'id': 'tt0120338', 'titleText': {'text': 'Titanic', 'isOriginalTitle': True}, 'originalTitleText': {'text': 'Titanic', 'isOriginalTitle': True}, 'releaseYear': {'__typename': 'YearRange', 'year': 1997, 'endYear': None}, 'releaseDate': {'__typename': 'ReleaseDate', 'month': 12, 'day': 19, 'year': 1997, 'country': {'id': 'US'}, 'restriction': None, 'attributes': [], 'displayableProperty': {'qualifiersInMarkdownList': None}}, 'titleType': {'__typename': 'TitleType', 'id': 'movie', 'text': 'Movie', 'categories': [{'id': 'movie', 'text': 'Movie', 'value': 'movie'}], 'canHaveEpisodes': False, 'isEpisode': False, 'isSeries': False, 'displayableProperty': {'value': {'plainText': ''}}}, 'primaryImage': {'__typename': 'Image', 'id': 'rm2647458304', 'url': 'https://m.media-amazon.com/images/M/MV5BYzYyN2FiZmUtYWYzMy00MzViLWJkZTMtOGY1ZjgzNWMwN2YxXkEyXkFqcGc@._V1_.jpg', 'height': 3000, 'width': 2015}, 'canRate': {'isRatable': True}, 'ratingsSummary': {'vo
# ...

# %%
import requests

url = "https://ott-details.p.rapidapi.com/gettitleDetails"

querystring = {"imdbid":"tt9904802"}

headers = {
	"x-rapidapi-key": "507b37df13msh479715189576570p16bfd8jsndb35155ca1b2",
	"x-rapidapi-host": "ott-details.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'message': 'You are not subscribed to this API.'}
